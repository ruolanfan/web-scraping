# %%
import os
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist

# %%
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'
a0 = requests.get(url).text
a0
# Out:
# '<!DOCTYPE html>\n<html lang=\'en\' xml:lang=\'en\' xmlns=\'http://www.w3.org/1999/xhtml\'>\n<head>\n<meta content=\'text/html; charset=utf-8\' http-equiv=\'Content-Type\'>\n<!-- Always force latest IE rendering engine or request Chrome Frame -->\n<meta content=\'IE=edge,chrome=1\' http-equiv=\'X-UA-Compatible\'>\n<script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":230,"agent":""}</script>\n<script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQcPUlZTDxAFXVRUBQEPVA==",licenseKey:"5e33925808",applicationID:"59562082"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==ty
# ...

# %%
soup = bs(a0,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":230,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
news_title = soup.find_all("div", class_ ="content_title")
news_title
# Out:
# [<div class="content_title">
#  <a href="/news/8508/nasa-invites-students-to-name-mars-2020-rover/">
#  NASA Invites Students to Name Mars 2020 Rover
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8442/nasas-curiosity-mars-rover-finds-a-clay-cache/">
#  NASA's Curiosity Mars Rover Finds a Clay Cache
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8436/why-this-martian-full-moon-looks-like-candy/">
#  Why This Martian Full Moon Looks Like Candy
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8426/nasa-garners-7-webby-award-nominations/">
#  NASA Garners 7 Webby Award Nominations
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8413/nasas-opportunity-rover-mission-on-mars-comes-to-end/">
#  NASA's Opportunity Rover Mission on Mars Comes to End
#  </a>
#  </div>, <div class="content_title">
#  <a href="/news/8402/nasas-insight-places-first-instrument-on-mars/">
#  NASA's InSight Places First Instrument on Mars
#  </a>
# ...

# %%
title = news_title[0].get_text()
title.strip()
# Out:
# 'NASA Invites Students to Name Mars 2020 Rover'

# %%
p0 = soup.find("div", class_="article_teaser_body")
print(p0)
# Out:
# None

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://twitter.com/marswxreport?lang=en'
a1 = requests.get(url).text
a1
# Out:
# '<!DOCTYPE html>\n<html lang="en" data-scribe-reduced-action-queue="true">\n  <head>\n    \n    \n    \n    \n    \n    \n    \n    <meta charset="utf-8">\n      <script  nonce="qruhO/jyhj6Ojk8Dwba76Q==">\n        !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();\n      </script>\n    \n    \n  \n  <script id="bouncer_terminate_iframe" nonce="qruhO/jyhj6Ojk8Dwba76Q==">\n    if (window.top != window) {\n  window.top.postMessage({\'bouncer\': true, \'event\': \'complete\'}, \'*\');\n}\n  </script>\n  <script id="swift_action_queue" nonce="qruhO/jyhj6Ojk8Dwba76Q==">\n    !function(){function e(e){if(e||(e=window.event),!e)return!1;if(e.timestamp=(new Date).getTime(),!e.target&&e.srcElement&&(e.target=e.srcElement),document.documentElement.getAttribute("data-scribe-reduced-action-queue"))for(var t=e.target;t&&t!=document.body;)
# ...

# %%
soup1 = bs(a1,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":230,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
latest_weather = soup.find_all("div", class_ ="js-tweet-text-container")
latest_weather
# Out:
# []
